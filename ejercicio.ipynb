# %% [markdown]
# # Análisis estático y dinámico

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: anyio==4.8.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 1)) (4.8.0)
# Requirement already satisfied: appnope==0.1.4 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 2)) (0.1.4)
# Requirement already satisfied: argon2-cffi==23.1.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 3)) (23.1.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 4)) (21.2.0)
# Requirement already satisfied: arrow==1.3.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: asttokens==3.0.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: async-lru==2.0.4 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 7)) (2.0.4)
# Requirement already satisfied: attrs==25.1.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 8)) (25.1.0)
# Requirement already satisfied: babel==2.17.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 9)) (2.17.0)
# Requirement already satisfied: beautifulsoup4==4.13.3 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 10)) (4.13.3)
# Requirement already satisfied: bleach==6.2.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 11)) (6.2.0)
# Requirement already satisfied: capstone==5.0.5 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 12)) (5.0.5)
# Requirement already satisfied: certifi==2025.1.31 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 13)) (2025.1.31)
# Requirement already satisfied: cffi==1.17.1 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 14)) (1.17.1)
# Requirement already satisfied: charset-normalizer==3.4.1 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 15)) (3.4.1)
# Requirement already satisfied: comm==0.2.2 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 16)) (0.2.2)
# Requirement already satisfied: debugpy==1.8.12 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 17)) (1.8.12)
# Requirement already satisfied: decorator==5.1.1 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 18)) (5.1.1)
# Requirement already satisfied: defusedxml==0.7.1 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 19)) (0.7.1)
# Requirement already satisfied: executing==2.2.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 20)) (2.2.0)
# Requirement already satisfied: fastjsonschema==2.21.1 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 21)) (2.21.1)
# Requirement already satisfied: fqdn==1.5.1 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 22)) (1.5.1)
# Requirement already satisfied: h11==0.14.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 23)) (0.14.0)
# Requirement already satisfied: httpcore==1.0.7 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 24)) (1.0.7)
# Requirement already satisfied: httpx==0.28.1 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 25)) (0.28.1)
# Requirement already satisfied: idna==3.10 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 26)) (3.10)
# Requirement already satisfied: ipykernel==6.29.5 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 27)) (6.29.5)
# Requirement already satisfied: ipython==8.32.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 28)) (8.32.0)
# Requirement already satisfied: ipywidgets==8.1.5 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 29)) (8.1.5)
# Requirement already satisfied: isoduration==20.11.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 30)) (20.11.0)
# Requirement already satisfied: jedi==0.19.2 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 31)) (0.19.2)
# Requirement already satisfied: Jinja2==3.1.5 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 32)) (3.1.5)
# Requirement already satisfied: json5==0.10.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 33)) (0.10.0)
# Requirement already satisfied: jsonpointer==3.0.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 34)) (3.0.0)
# Requirement already satisfied: jsonschema==4.23.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 35)) (4.23.0)
# Requirement already satisfied: jsonschema-specifications==2024.10.1 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 36)) (2024.10.1)
# Requirement already satisfied: jupyter==1.1.1 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 37)) (1.1.1)
# Requirement already satisfied: jupyter-console==6.6.3 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 38)) (6.6.3)
# Requirement already satisfied: jupyter-events==0.12.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 39)) (0.12.0)
# Requirement already satisfied: jupyter-lsp==2.2.5 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 40)) (2.2.5)
# Requirement already satisfied: jupyter_client==8.6.3 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 41)) (8.6.3)
# Requirement already satisfied: jupyter_core==5.7.2 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 42)) (5.7.2)
# Requirement already satisfied: jupyter_server==2.15.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 43)) (2.15.0)
# Requirement already satisfied: jupyter_server_terminals==0.5.3 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 44)) (0.5.3)
# Requirement already satisfied: jupyterlab==4.3.5 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 45)) (4.3.5)
# Requirement already satisfied: jupyterlab_pygments==0.3.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 46)) (0.3.0)
# Requirement already satisfied: jupyterlab_server==2.27.3 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 47)) (2.27.3)
# Requirement already satisfied: jupyterlab_widgets==3.0.13 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 48)) (3.0.13)
# Requirement already satisfied: MarkupSafe==3.0.2 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 49)) (3.0.2)
# Requirement already satisfied: matplotlib-inline==0.1.7 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 50)) (0.1.7)
# Requirement already satisfied: mistune==3.1.1 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 51)) (3.1.1)
# Requirement already satisfied: nbclient==0.10.2 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 52)) (0.10.2)
# Requirement already satisfied: nbconvert==7.16.6 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 53)) (7.16.6)
# Requirement already satisfied: nbformat==5.10.4 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 54)) (5.10.4)
# Requirement already satisfied: nest-asyncio==1.6.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 55)) (1.6.0)
# Requirement already satisfied: notebook==7.3.2 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 56)) (7.3.2)
# Requirement already satisfied: notebook_shim==0.2.4 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 57)) (0.2.4)
# Requirement already satisfied: overrides==7.7.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 58)) (7.7.0)
# Requirement already satisfied: packaging==24.2 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 59)) (24.2)
# Requirement already satisfied: pandocfilters==1.5.1 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 60)) (1.5.1)
# Requirement already satisfied: parso==0.8.4 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 61)) (0.8.4)
# Requirement already satisfied: pefile==2024.8.26 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 62)) (2024.8.26)
# Requirement already satisfied: pexpect==4.9.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 63)) (4.9.0)
# Requirement already satisfied: platformdirs==4.3.6 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 64)) (4.3.6)
# Requirement already satisfied: prometheus_client==0.21.1 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 65)) (0.21.1)
# Requirement already satisfied: prompt_toolkit==3.0.50 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 66)) (3.0.50)
# Requirement already satisfied: psutil==7.0.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 67)) (7.0.0)
# Requirement already satisfied: ptyprocess==0.7.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 68)) (0.7.0)
# Requirement already satisfied: pure_eval==0.2.3 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 69)) (0.2.3)
# Requirement already satisfied: pycparser==2.22 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 70)) (2.22)
# Requirement already satisfied: Pygments==2.19.1 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 71)) (2.19.1)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 72)) (2.9.0.post0)
# Requirement already satisfied: python-json-logger==3.2.1 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 73)) (3.2.1)
# Requirement already satisfied: PyYAML==6.0.2 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 74)) (6.0.2)
# Requirement already satisfied: pyzmq==26.2.1 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 75)) (26.2.1)
# Requirement already satisfied: referencing==0.36.2 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 76)) (0.36.2)
# Requirement already satisfied: requests==2.32.3 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 77)) (2.32.3)
# Requirement already satisfied: rfc3339-validator==0.1.4 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 78)) (0.1.4)
# Requirement already satisfied: rfc3986-validator==0.1.1 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 79)) (0.1.1)
# Requirement already satisfied: rpds-py==0.22.3 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 80)) (0.22.3)
# Requirement already satisfied: Send2Trash==1.8.3 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 81)) (1.8.3)
# Requirement already satisfied: setuptools==75.8.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 82)) (75.8.0)
# Requirement already satisfied: six==1.17.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 83)) (1.17.0)
# Requirement already satisfied: sniffio==1.3.1 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 84)) (1.3.1)
# Requirement already satisfied: soupsieve==2.6 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 85)) (2.6)
# Requirement already satisfied: stack-data==0.6.3 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 86)) (0.6.3)
# Requirement already satisfied: terminado==0.18.1 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 87)) (0.18.1)
# Requirement already satisfied: tinycss2==1.4.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 88)) (1.4.0)
# Requirement already satisfied: tornado==6.4.2 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 89)) (6.4.2)
# Requirement already satisfied: traitlets==5.14.3 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 90)) (5.14.3)
# Requirement already satisfied: types-python-dateutil==2.9.0.20241206 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 91)) (2.9.0.20241206)
# Requirement already satisfied: typing_extensions==4.12.2 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 92)) (4.12.2)
# Requirement already satisfied: uri-template==1.3.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 93)) (1.3.0)
# Requirement already satisfied: urllib3==2.3.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 94)) (2.3.0)
# Requirement already satisfied: wcwidth==0.2.13 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 95)) (0.2.13)
# Requirement already satisfied: webcolors==24.11.1 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 96)) (24.11.1)
# Requirement already satisfied: webencodings==0.5.1 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 97)) (0.5.1)
# Requirement already satisfied: websocket-client==1.8.0 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 98)) (1.8.0)
# Requirement already satisfied: widgetsnbextension==4.0.13 in ./myvenv/lib/python3.13/site-packages (from -r requirements.txt (line 99)) (4.0.13)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Análisis estático

# %%
import pefile
from datetime import datetime, timezone
from capstone import Cs, CS_ARCH_X86, CS_MODE_32

# %%
pe = pefile.PE("examples/sample_vg655_25th.exe")


print("Secciones del ejecutable:")
for section in pe.sections:
    print(f"Nombre: {section.Name.decode().strip()}, Tamaño Raw: {section.SizeOfRawData}, Tamaño Virtual: {section.Misc_VirtualSize}")

# Buscar posibles indicadores de empaquetado (UPX)
for section in pe.sections:
    if b"UPX" in section.Name:
        print("\n🔍 Posible empaquetado detectado con UPX.")
        break
else:
    print("\n✅ No se detectaron indicios claros de empaquetado.")
# Out:
# Secciones del ejecutable:
# Nombre: .text, Tamaño Raw: 28672, Tamaño Virtual: 27056
# Nombre: .rdata, Tamaño Raw: 24576, Tamaño Virtual: 24432
# Nombre: .data, Tamaño Raw: 8192, Tamaño Virtual: 6488
# Nombre: .rsrc, Tamaño Raw: 3448832, Tamaño Virtual: 3448736
#
# ✅ No se detectaron indicios claros de empaquetado.

# %% [markdown]
# 1.
#     - ¿Se encuentran empaquetados los ejecutable?
#         * No hay secciones con nombres como .UPX0 o .UPX1.
#         * Los tamaños Raw y Virtual son consistentes (cuando están empaquetados, suele haber una gran diferencia)
#
#     - ¿Cómo lo puede determinar?
#         * Se verificaron las secciones del ejecutable y no se encontraron patrones relacionados con empaquetadores conocidos como UPX
#         * No hay una diferencia muy notable entre el tamaño en crudo y el virtual
#         * No hay nombres o terminacines con .UPX

# %%
suspicious_api_calls = {
    "process hollowing": {
        "CreateProcess", "GetModuleHandle", "GetProcAddress", "VirtualAllocEx", "WriteProcessMemory", "SetThreadContext", "ResumeThread"
    },
    "create remote thread": {
        "OpenProcess", "GetModuleHandle", "GetProcAddress", "VirtualAllocEx", "WriteProcessMemory", "CreateRemoteThread"
    },
    "enumerating processes": {
        "CreateToolhelp32Snapshot", "Process32First", "Process32Next", "WTSEnumerateProcesses"
    },
    "drop file from PE resource": {
        "GetModuleHandle", "FindResource", "LoadResource", "CreateFileA"
    },
    "IAT hooking": {
        "GetModuleHandle", "strcmp", "VirtualProtect"
    },
    "delete itself": {
        "GetModuleFileName", "ExitProcess", "DeleteFile"
    },
    "download and execute PE file": {
        "URLDownloadToFile", "ShellExecute"
    },
    "bind TCP port": {
        "WSAStartup", "socket"
    },
    "capture network traffic": {
        "socket", "bind", "WSAIoctl", "recvfrom"
    }
}

# %%
dll_function_usage = {}
suspicious_matches = {}

print("\n🔍 Análisis de DLLs y funciones utilizadas:")
for entry in getattr(pe, 'DIRECTORY_ENTRY_IMPORT', []):
    dll_name = entry.dll.decode('utf-8')
    dll_function_usage[dll_name] = []
    print(f"\n📁 DLL: {dll_name}")
    for imp in entry.imports:
        func_name = imp.name.decode('utf-8') if imp.name else "N/A"
        dll_function_usage[dll_name].append(func_name)
        print(f"    ↳ {func_name}")

        # Comparar con las llamadas maliciosas de la tabla 3
        for activity, apis in suspicious_api_calls.items():
            if func_name in apis:
                suspicious_matches.setdefault(activity, []).append(func_name)

# Imprimir resultados de comparación
if suspicious_matches:
    print("\nSe encontraron posibles comportamientos maliciosos:")
    for activity, functions in suspicious_matches.items():
        print(f"- {activity}: {', '.join(functions)}")
else:
    print("\nNo se encontraron comportamientos maliciosos según la Tabla 3.")

# Cerrar el archivo PE
pe.close()
# Out:
# 🔍 Análisis de DLLs y funciones utilizadas:
#
# 📁 DLL: KERNEL32.dll
#     ↳ GetFileAttributesW
#     ↳ GetFileSizeEx
#     ↳ CreateFileA
#     ↳ InitializeCriticalSection
#     ↳ DeleteCriticalSection
#     ↳ ReadFile
#     ↳ GetFileSize
#     ↳ WriteFile
#     ↳ LeaveCriticalSection
#     ↳ EnterCriticalSection
#     ↳ SetFileAttributesW
#     ↳ SetCurrentDirectoryW
#     ↳ CreateDirectoryW
#     ↳ GetTempPathW
#     ↳ GetWindowsDirectoryW
#     ↳ GetFileAttributesA
#     ↳ SizeofResource
#     ↳ LockResource
#     ↳ LoadResource
#     ↳ MultiByteToWideChar
#     ↳ Sleep
#     ↳ OpenMutexA
#     ↳ GetFullPathNameA
#     ↳ CopyFileA
#     ↳ GetModuleFileNameA
#     ↳ VirtualAlloc
#     ↳ VirtualFree
#     ↳ FreeLibrary
#     ↳ HeapAlloc
#     ↳ GetProcessHeap
#     ↳ GetModuleHandleA
#     ↳ SetLastError
#     ↳ VirtualProtect
#     ↳ IsBadReadPtr
#     ↳ HeapFree
#     ↳ SystemTimeToFileTime
#     ↳ LocalFileTimeToFileTime
#     ↳ CreateDirectoryA
#     ↳ GetStartupInfoA
#     ↳ SetFilePointer
#     ↳ SetFileTime
#     ↳ GetComputerNameW
#     ↳ GetCurrentDirectoryA
#     ↳ SetCurrentDirectoryA
#     ↳ GlobalAlloc
#     ↳ LoadLibraryA
#     ↳ GetProcAddress
#     ↳ GlobalFree
#     ↳ CreateProcessA
#     ↳ CloseHandle
#     ↳ WaitForSingleObject
#     ↳ TerminateProcess
#     ↳ GetExitCodeProcess
#     ↳ FindResourceA
#
# 📁 DLL: USER32.dll
#     ↳ wsprintfA
#
# 📁 DLL: ADVAPI32.dll
#     ↳ CreateServiceA
#     ↳ OpenServiceA
#     ↳ StartServiceA
#     ↳ CloseServiceHandle
#     ↳ CryptReleaseContext
#     ↳ RegCreateKeyW
#     ↳ RegSetValueExA
#     ↳ RegQueryValueExA
#     ↳ RegCloseKey
#     ↳ OpenSCManagerA
#
# 📁 DLL: MSVCRT.dll
#     ↳ realloc
#     ↳ fclose
#     ↳ fwrite
#     ↳ fread
#     ↳ fopen
#     ↳ sprintf
#     ↳ rand
#     ↳ srand
#     ↳ strcpy
#     ↳ memset
#     ↳ strlen
#     ↳ wcscat
#     ↳ wcslen
#     ↳ __CxxFrameHandler
#     ↳ ??3@YAXPAX@Z
#     ↳ memcmp
#     ↳ _except_handler3
#     ↳ _local_unwind2
#     ↳ wcsrchr
#     ↳ swprintf
#     ↳ ??2@YAPAXI@Z
#     ↳ memcpy
#     ↳ strcmp
#     ↳ strrchr
#     ↳ __p___argv
#     ↳ __p___argc
#     ↳ _stricmp
#     ↳ free
#     ↳ malloc
#     ↳ ??0exception@@QAE@ABV0@@Z
#     ↳ ??1exception@@UAE@XZ
#     ↳ ??0exception@@QAE@ABQBD@Z
#     ↳ _CxxThrowException
#     ↳ calloc
#     ↳ strcat
#     ↳ _mbsstr
#     ↳ ??1type_info@@UAE@XZ
#     ↳ _exit
#     ↳ _XcptFilter
#     ↳ exit
#     ↳ _acmdln
#     ↳ __getmainargs
#     ↳ _initterm
#     ↳ __setusermatherr
#     ↳ _adjust_fdiv
#     ↳ __p__commode
#     ↳ __p__fmode
#     ↳ __set_app_type
#     ↳ _controlfp
#
# Se encontraron posibles comportamientos maliciosos:
# - drop file from PE resource: CreateFileA, LoadResource
# - IAT hooking: VirtualProtect, strcmp
# - process hollowing: GetProcAddress
# - create remote thread: GetProcAddress

# %% [markdown]
# 2.
#     - ¿Hay indicios de algún comportamiento malicioso en base a la comparación? Justifique su respuesta.
#         * Sí, si hay indicios.
#         * CreateFileA y LoadResource son funciones se usan a veces para sacar archivos escondidos de un programa, algo típico de malware que quiere dejar archivos maliciosos
#         * VirtualProtect y strcmp suelen usarse para modificar la memoria de un programa, lo que es un truco que usan los virus para esconderse
#         * GetProcAddress función común en virus que intentan encontrar funciones importantes para infectar o manipular otros procesos
#         * CreateRemoteThread a veces la usan para meterse en otros procesos que están funcionando
#
#     * sí, hay indicios sospechosos de que este programa podría estar haciendo algo malicioso, basándonos en las funciones que usa y su relación con lo que vimos en la Tabla 3 del artículo

# %%
timestamp = pe.FILE_HEADER.TimeDateStamp
compilation_date = datetime.fromtimestamp(timestamp, timezone.utc).strftime('%Y-%m-%d %H:%M:%S')

print(f"🗓️ El ejecutable fue compilado el: {compilation_date}")

# Cerrar el archivo PE
pe.close()
# Out:
# 🗓️ El ejecutable fue compilado el: 2010-11-20 09:05:05

# %%
executables = [
    "examples/sample_vg655_25th.exe",
    "examples/sample_qwrty_dk2"
]

for exe_file in executables:
    print(f"\n🔍 Análisis de ensamblador para: {exe_file}")

    # Cargar el ejecutable
    pe = pefile.PE(exe_file)

    # Obtener punto de entrada
    entrypoint = pe.OPTIONAL_HEADER.AddressOfEntryPoint
    entrypoint_address = entrypoint + pe.OPTIONAL_HEADER.ImageBase

    # Obtener los primeros 200 bytes desde el punto de entrada
    binary_code = pe.get_memory_mapped_image()[entrypoint:entrypoint+200]

    # Inicializar el desensamblador
    disassembler = Cs(CS_ARCH_X86, CS_MODE_32)

    # Desensamblar y mostrar las instrucciones
    for instruction in disassembler.disasm(binary_code, entrypoint_address):
        print(f"0x{instruction.address:x}:\t{instruction.mnemonic}\t{instruction.op_str}")

    # Cerrar el archivo
    pe.close()
# Out:
# 🔍 Análisis de ensamblador para: examples/sample_vg655_25th.exe
# 0x4077ba:	push	ebp
# 0x4077bb:	mov	ebp, esp
# 0x4077bd:	push	-1
# 0x4077bf:	push	0x40d488
# 0x4077c4:	push	0x4076f4
# 0x4077c9:	mov	eax, dword ptr fs:[0]
# 0x4077cf:	push	eax
# 0x4077d0:	mov	dword ptr fs:[0], esp
# 0x4077d7:	sub	esp, 0x68
# 0x4077da:	push	ebx
# 0x4077db:	push	esi
# 0x4077dc:	push	edi
# 0x4077dd:	mov	dword ptr [ebp - 0x18], esp
# 0x4077e0:	xor	ebx, ebx
# 0x4077e2:	mov	dword ptr [ebp - 4], ebx
# 0x4077e5:	push	2
# 0x4077e7:	call	dword ptr [0x4081c4]
# 0x4077ed:	pop	ecx
# 0x4077ee:	or	dword ptr [0x40f94c], 0xffffffff
# 0x4077f5:	or	dword ptr [0x40f950], 0xffffffff
# 0x4077fc:	call	dword ptr [0x4081c0]
# 0x407802:	mov	ecx, dword ptr [0x40f948]
# 0x407808:	mov	dword ptr [eax], ecx
# 0x40780a:	call	dword ptr [0x4081bc]
# 0x407810:	mov	ecx, dword ptr [0x40f944]
# 0x407816:	mov	dword ptr [eax], ecx
# 0x407818:	mov	eax, dword ptr [0x4081b8]
# 0x40781d:	mov	eax, dword ptr [eax]
# 0x40781f:	mov	dword ptr [0x40f954], eax
# 0x407824:	call	0x40793f
# 0x407829:	cmp	dword ptr [0x40f870], ebx
# 0x40782f:	jne	0x40783d
# 0x407831:	push	0x40793c
# 0x407836:	call	dword ptr [0x4081b4]
# 0x40783c:	pop	ecx
# 0x40783d:	call	0x40792a
# 0x407842:	push	0x40e00c
# 0x407847:	push	0x40e008
# 0x40784c:	call	0x407924
# 0x407851:	mov	eax, dword ptr [0x40f940]
# 0x407856:	mov	dword ptr [ebp - 0x6c], eax
# 0x407859:	lea	eax, [ebp - 0x6c]
# 0x40785c:	push	eax
# 0x40785d:	push	dword ptr [0x40f93c]
# 0x407863:	lea	eax, [ebp - 0x64]
# 0x407866:	push	eax
# 0x407867:	lea	eax, [ebp - 0x70]
# 0x40786a:	push	eax
# 0x40786b:	lea	eax, [ebp - 0x60]
# 0x40786e:	push	eax
# 0x40786f:	call	dword ptr [0x4081ac]
# 0x407875:	push	0x40e004
# 0x40787a:	push	0x40e000
#
# 🔍 Análisis de ensamblador para: examples/sample_qwrty_dk2
# 0x406da0:	pushal
# 0x406da1:	mov	esi, 0x406000
# 0x406da6:	lea	edi, [esi - 0x5000]
# 0x406dac:	push	edi
# 0x406dad:	or	ebp, 0xffffffff
# 0x406db0:	jmp	0x406dc2
# 0x406db2:	nop
# 0x406db3:	nop
# 0x406db4:	nop
# 0x406db5:	nop
# 0x406db6:	nop
# 0x406db7:	nop
# 0x406db8:	mov	al, byte ptr [esi]
# 0x406dba:	inc	esi
# 0x406dbb:	mov	byte ptr [edi], al
# 0x406dbd:	inc	edi
# 0x406dbe:	add	ebx, ebx
# 0x406dc0:	jne	0x406dc9
# 0x406dc2:	mov	ebx, dword ptr [esi]
# 0x406dc4:	sub	esi, -4
# 0x406dc7:	adc	ebx, ebx
# 0x406dc9:	jb	0x406db8
# 0x406dcb:	mov	eax, 1
# 0x406dd0:	add	ebx, ebx
# 0x406dd2:	jne	0x406ddb
# 0x406dd4:	mov	ebx, dword ptr [esi]
# 0x406dd6:	sub	esi, -4
# 0x406dd9:	adc	ebx, ebx
# 0x406ddb:	adc	eax, eax
# 0x406ddd:	add	ebx, ebx
# 0x406ddf:	jae	0x406dd0
# 0x406de1:	jne	0x406dec
# 0x406de3:	mov	ebx, dword ptr [esi]
# 0x406de5:	sub	esi, -4
# 0x406de8:	adc	ebx, ebx
# 0x406dea:	jae	0x406dd0
# 0x406dec:	xor	ecx, ecx
# 0x406dee:	sub	eax, 3
# 0x406df1:	jb	0x406e00
# 0x406df3:	shl	eax, 8
# 0x406df6:	mov	al, byte ptr [esi]
# 0x406df8:	inc	esi
# 0x406df9:	xor	eax, 0xffffffff
# 0x406dfc:	je	0x406e72
# 0x406dfe:	mov	ebp, eax
# 0x406e00:	add	ebx, ebx
# 0x406e02:	jne	0x406e0b
# 0x406e04:	mov	ebx, dword ptr [esi]
# 0x406e06:	sub	esi, -4
# 0x406e09:	adc	ebx, ebx
# 0x406e0b:	adc	ecx, ecx
# 0x406e0d:	add	ebx, ebx
# 0x406e0f:	jne	0x406e18
# 0x406e11:	mov	ebx, dword ptr [esi]
# 0x406e13:	sub	esi, -4
# 0x406e16:	adc	ebx, ebx
# 0x406e18:	adc	ecx, ecx
# 0x406e1a:	jne	0x406e3c
# 0x406e1c:	inc	ecx
# 0x406e1d:	add	ebx, ebx
# 0x406e1f:	jne	0x406e28
# 0x406e21:	mov	ebx, dword ptr [esi]
# 0x406e23:	sub	esi, -4
# 0x406e26:	adc	ebx, ebx
# 0x406e28:	adc	ecx, ecx
# 0x406e2a:	add	ebx, ebx
# 0x406e2c:	jae	0x406e1d
# 0x406e2e:	jne	0x406e39
# 0x406e30:	mov	ebx, dword ptr [esi]
# 0x406e32:	sub	esi, -4
# 0x406e35:	adc	ebx, ebx
# 0x406e37:	jae	0x406e1d
# 0x406e39:	add	ecx, 2
# 0x406e3c:	cmp	ebp, 0xfffff300
# 0x406e42:	adc	ecx, 1
# 0x406e45:	lea	edx, [edi + ebp]
# 0x406e48:	cmp	ebp, -4
# 0x406e4b:	jbe	0x406e5c
# 0x406e4d:	mov	al, byte ptr [edx]
# 0x406e4f:	inc	edx
# 0x406e50:	mov	byte ptr [edi], al
# 0x406e52:	inc	edi
# 0x406e53:	dec	ecx
# 0x406e54:	jne	0x406e4d
# 0x406e56:	jmp	0x406dbe
# 0x406e5b:	nop
# 0x406e5c:	mov	eax, dword ptr [edx]
# 0x406e5e:	add	edx, 4
# 0x406e61:	mov	dword ptr [edi], eax
# 0x406e63:	add	edi, 4
